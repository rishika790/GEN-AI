# %%
from langchain_community.document_loaders import PyPDFLoader
Loader = PyPDFLoader("Rishika_Gour_Resume.pdf")
doc = Loader.load()
# Out:
# C:\Users\rgour\AppData\Local\Temp\ipykernel_38032\2734256310.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
type(doc[0])
# Out:
# langchain_core.documents.base.Document

# %%
for x in doc:
    print(x.page_content)
# Out:
# Rishika Gour
# B.Tech in Information Technology | Government Women Engineering College, Ajmer
# Email: rgour9320@gmail.com | Phone: +91 7976436292 | City: Beawar, Rajasthan
# Objective
# Motivated and passionate B.Tech student with strong skills in programming and data science,
# seeking a Software Engineering Internship at Google to enhance technical skills and contribute to
# impactful projects.
# Education
# B.Tech in Information Technology
# Government Women Engineering College, Ajmer
# Current Year: 3rd | Expected Graduation: 2026
# Technical Skills
# - Programming: Python, C, C++
# - Concepts: Data Structures & Algorithms
# - Tools/Libraries: Pandas, NumPy, Matplotlib, Scikit-learn, Git, GitHub
# Projects
# PhishGuard (Web Security Project) – Built a phishing detection system using Machine Learning
# to identify fake websites.
# Crop Prediction System – Predicted the best crop to grow based on soil and weather data using
# Random Forest Classifier.
# ...

# %%
# from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
final_docs = text_splitter.split_documents(doc)
final_docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-28T03:33:45+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-28T03:33:45+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'Rishika_Gour_Resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Rishika Gour\nB.Tech in Information Technology | Government Women Engineering College, Ajmer\nEmail: rgour9320@gmail.com | Phone: +91 7976436292 | City: Beawar, Rajasthan\nObjective\nMotivated and passionate B.Tech student with strong skills in programming and data science,\nseeking a Software Engineering Internship at Google to enhance technical skills and contribute to\nimpactful projects.\nEducation\nB.Tech in Information Technology\nGovernment Women Engineering College, Ajmer\nCurrent Year: 3rd | Expected Graduation: 2026\nTechnical Skills\n- Programming: Python, C, C++\n- Concepts: 
# ...

# %%
print(final_docs[0])
# Out:
# page_content='Rishika Gour
# B.Tech in Information Technology | Government Women Engineering College, Ajmer
# Email: rgour9320@gmail.com | Phone: +91 7976436292 | City: Beawar, Rajasthan
# Objective
# Motivated and passionate B.Tech student with strong skills in programming and data science,
# seeking a Software Engineering Internship at Google to enhance technical skills and contribute to
# impactful projects.
# Education
# B.Tech in Information Technology
# Government Women Engineering College, Ajmer
# Current Year: 3rd | Expected Graduation: 2026
# Technical Skills
# - Programming: Python, C, C++
# - Concepts: Data Structures & Algorithms
# - Tools/Libraries: Pandas, NumPy, Matplotlib, Scikit-learn, Git, GitHub
# Projects
# PhishGuard (Web Security Project) – Built a phishing detection system using Machine Learning
# to identify fake websites.
# Crop Prediction System – Predicted the best crop to grow based on soil and weather data using
# ...

# %%
# from langchain_community.document_loader import Textloader
# loader = textloader("hello.txt")
from langchain_community.document_loaders import TextLoader
loader = TextLoader("hello.txt")

# %%
docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=10)

# %%
final_text = text_splitter.split_documents(docs)

# %%
print(final_text)
# Out:
# [Document(metadata={'source': 'hello.txt'}, page_content='Hello, good morning/afternoon everyone.'), Document(metadata={'source': 'hello.txt'}, page_content='â€‹My name is Rishika Gour. I am originally from Beawar and currently based in Jaipur for my'), Document(metadata={'source': 'hello.txt'}, page_content='for my professional upskilling. I am pursuing my graduation in [Insert your degree here, e.g.,'), Document(metadata={'source': 'hello.txt'}, page_content='e.g., B.Tech/BCA] with a specialization in Computer Science.Through this training, I am gaining'), Document(metadata={'source': 'hello.txt'}, page_content='gaining hands-on experience with live projects, data analysis, and building AI models. I love'), Document(metadata={'source': 'hello.txt'}, page_content='I love solving problems and converting raw data into meaningful insights.'), Document(metadata={'source': 'hello.txt'}, page_content='â€‹Apart from tech, I consider myself a quick learner, highly adaptable to new environme
# ...

# %%
for x in final_text:
    print(x.page_content)
# Out:
# Hello, good morning/afternoon everyone.
# â€‹My name is Rishika Gour. I am originally from Beawar and currently based in Jaipur for my
# for my professional upskilling. I am pursuing my graduation in [Insert your degree here, e.g.,
# e.g., B.Tech/BCA] with a specialization in Computer Science.Through this training, I am gaining
# gaining hands-on experience with live projects, data analysis, and building AI models. I love
# I love solving problems and converting raw data into meaningful insights.
# â€‹Apart from tech, I consider myself a quick learner, highly adaptable to new environments, and
# and someone who stands firm on clear communication. I am eager to bring my dedication and technical
# technical skills to a dynamic team through this opportunity. Thank you."

# %%
### normal doc text convert into doc
with open ("hello.txt") as file:
    file = file.read()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=10)
    text= text_splitter.create_documents([file])

# %%
print(text[0])
# Out:
# page_content='Hello, good morning/afternoon everyone.'

# %%
#print(text)
text
# Out:
# [Document(metadata={}, page_content='Hello, good morning/afternoon everyone.'),
#  Document(metadata={}, page_content='â€‹My name is Rishika Gour. I am originally from Beawar and currently based in Jaipur for my'),
#  Document(metadata={}, page_content='for my professional upskilling. I am pursuing my graduation in [Insert your degree here, e.g.,'),
#  Document(metadata={}, page_content='e.g., B.Tech/BCA] with a specialization in Computer Science.Through this training, I am gaining'),
#  Document(metadata={}, page_content='gaining hands-on experience with live projects, data analysis, and building AI models. I love'),
#  Document(metadata={}, page_content='I love solving problems and converting raw data into meaningful insights.'),
#  Document(metadata={}, page_content='â€‹Apart from tech, I consider myself a quick learner, highly adaptable to new environments, and'),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(docs)

# %%
print("Total Chunks:", len(chunks))
# Out:
# Total Chunks: 2

# %%
len(chunks[0].page_content)
# Out:
# 463

# %%
#length find chunks

# %%
# task 
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rgour\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rgour\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\rgour\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

text = docs[0].page_content

sentences = sent_tokenize(text)

print("Total Sentences:", len(sentences))
print(sentences[:5])
# Out:
# Total Sentences: 8
# ['Hello, good morning/afternoon everyone.', 'â€‹My name is Rishika Gour.', 'I am originally from Beawar and currently based in Jaipur for my professional upskilling.', 'I am pursuing my graduation in [Insert your degree here, e.g., B.Tech/BCA] with a specialization in Computer Science.Through this training, I am gaining hands-on experience with live projects, data analysis, and building AI models.', 'I love solving problems and converting raw data into meaningful insights.']

# %%
from langchain_community.document_loaders import PythonLoader
loader = PythonLoader("python.py")
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'python.py'}, page_content='def factorial(n):\n    fact = 1\n\n    for i in range(1, n + 1):\n        fact *= i\n\n    return fact\n\nnum = int(input("Enter a number: "))\nprint("Factorial =", factorial(num))')]

# %%
for doc in docs:
    print(doc.page_content)
# Out:
# def factorial(n):
#     fact = 1
#
#     for i in range(1, n + 1):
#         fact *= i
#
#     return fact
#
# num = int(input("Enter a number: "))
# print("Factorial =", factorial(num))

# %%
from langchain_text_splitters import PythonCodeTextSplitter
total_text = PythonCodeTextSplitter(chunk_size=10, chunk_overlap=3)

# %%
final_result = total_text.split_documents(docs)

# %%
final_result
# Out:
# [Document(metadata={'source': 'python.py'}, page_content='def'),
#  Document(metadata={'source': 'python.py'}, page_content='factorial'),
#  Document(metadata={'source': 'python.py'}, page_content='ial(n):'),
#  Document(metadata={'source': 'python.py'}, page_content='fact'),
#  Document(metadata={'source': 'python.py'}, page_content='= 1'),
#  Document(metadata={'source': 'python.py'}, page_content='for i'),
#  Document(metadata={'source': 'python.py'}, page_content='i in'),
#  Document(metadata={'source': 'python.py'}, page_content='range(1,'),
#  Document(metadata={'source': 'python.py'}, page_content='n + 1):'),
#  Document(metadata={'source': 'python.py'}, page_content='fact'),
#  Document(metadata={'source': 'python.py'}, page_content='*= i'),
#  Document(metadata={'source': 'python.py'}, page_content='return'),
#  Document(metadata={'source': 'python.py'}, page_content='fact'),
#  Document(metadata={'source': 'python.py'}, page_content='num ='),
# ...
