# %%
import os
openai_api_key = os.getenv("OPEN_AI_API")
from dotenv import load_dotenv
load_dotenv()

huggingface_api_key = os.getenv("HUGGINGFACE_API_KEY")

# %%
huggingface_api_key

# %%
model_name = "all-MiniLM-L6-v2"

# %%
from langchain_huggingface import HuggingFaceEmbeddings
hugging_face_embeddings = HuggingFaceEmbeddings(model_name=model_name)

# %%
text = "Hello, how are you?"
output_embedding = hugging_face_embeddings.embed_query(text)

# %%
output_embedding

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings

# %%
loader = PyPDFLoader("Rishika_Gour_Resume.pdf")

documents = loader.load()

# %%
documents[0]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

docs = text_splitter.split_documents(documents)

# %%
len(docs)

# %%
embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vector = embedding.embed_query(docs[0].page_content)

# %%
len(vector)

# %%
embeddings = embedding.embed_documents(
    [doc.page_content for doc in docs]
)

# %%
len(embeddings)

# %%
len(embeddings[0])
